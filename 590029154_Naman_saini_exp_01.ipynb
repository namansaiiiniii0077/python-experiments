# %% [markdown]
# <a href="https://colab.research.google.com/github/namansaiiiniii0077/python-experiments/blob/main/590029154_Naman_saini_exp_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello world")
# Out:
# hello world

# %% [markdown]
# ***1.Variables***

# %%
#storing text data
item1 = "food"
item2 = "fare"
item3 = "shopping"

#print all travel expense items:
print("travel expense items: ", item1,";", item2, ";", item3 )
# Out:
# travel expense items:  food ; fare ; shopping

# %%
# travel expenditure
food = 230.5
fare = 2000
shopping = 500
print(food+fare+shopping)
# Out:
# 2730.5

# %% [markdown]
# ***2.Numbers***

# %%
# some mathematical operatins
x=12

print(x+5)
print(x-5)
print(x/5)
print(x//5)
print(x%5)
print(x*2)
print(x**2)
# Out:
# 17
# 7
# 2.4
# 2
# 2
# 24
# 144

# %%
# 10+2*3
a= 6-5.7

# to get expected just round
print(a)
type(a)
# Out:
# 0.2999999999999998
# float

# %%
# rounding after decimal point
x, y = 569, 65
a = x/y
print(a)  #float

#expected output: 8.75
round(a,2)
# Out:
# 8.753846153846155
# 8.75

# %%
# find the perimeter of a rectangle (P = 2(length + width))
length = 34
width = 44
P= 2*(length + width)
print (P)
# Out:
# 156

# %%
# to take the input from the user
length = int(input("enter the length"))
width = int(input("enter the width"))

p= 2*(length + width)
print (p)
# Out:
# enter the length4
# enter the width3
# 14

# %% [markdown]
# ***3.Strings***

# %%
text = "hello world"
text
# Out:
# 'hello world'

# %%
text = "hello world"
text[6]
# Out:
# 'w'

# %%
text = "hello world"
text[6:11]
# Out:
# 'world'

# %%
text = "hello world"
text[0:11:2]
# Out:
# 'hlowrd'

# %%
text = "hello world"
text[-1:-12:-1]
# Out:
# 'dlrow olleh'

# %%
text = "hello world" #index[start(included):stop(excluded) step(s)]
text[::-1]
# Out:
# 'dlrow olleh'

# %%
# strings are immutable: means once created then it can't be changed
text = "hello world"
# text[1] = "a" # This line causes the TypeError because strings are immutable

# To 'change' a string, you must create a new one. For example, to change the character at index 1:
text = text[0] + "a" + text[2:]
print(text)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1205758011.py in <cell line: 0>()
#       1 text = "hello world"
#       2
# ----> 3 text[1] = "a"
#
# TypeError: 'str' object does not support item assignment

# %%
a = "10"
b = "20"
x = a+b
print(x) # prints 1020
print(type(x))
# Out:
# 1020
# <class 'str'>

# %%
s1 = 'hello '
s2 = '23'
print(s1+s2)
# Out:
# hello 23

# %% [markdown]
# ***4.Lists***

# %%
# example mart
items = ['rice', 'oil', 'bread', 'fruits', 'milk']
print(items)
# Out:
# ['rice', 'oil', 'bread', 'fruits', 'milk']

# %%
items = ['rice', 'oil', 'bread', 'fruits', 'milk']
items[0:5:2]
# Out:
# ['rice', 'bread', 'milk']

# %%
items[0:5:2]
# Out:
# ['rice', 'bread', 'milk']

# %%
# WAP that asks user to enter a number and program should tell whetherb a number is even or odd
num = int(input("enter a number: "))
if num % 2 == 0:
    print(num, "number is even")
else:
    print(num, "number is odd")
# Out:
# enter a number: 5
# 5 number is odd

# %%
# WAP to ask user a dish name and it should print from which cuisine is that dish

# %% [markdown]
# ***6.For statements***

# %%
# WAP to store monthly expenses in a list and find out total expenses using for loop
expenses = [ 2300, 6900, 7856, 2569, 1498 ]
total = 0
for item in expenses:
    total = total + item
print(total)
# Out:
# 21123

# %%
# print 1 to 10 using range()
for i in range(1,11,2):
    print(i)
# Out:
# 1
# 3
# 5
# 7
# 9

# %%
# WAP to store monthly expenses in a list and find out total expenses
expenses = [ 2300, 6900, 7856, 2569, 1498 ]
Total = expenses[0] + expenses[1] + expenses[2] + expenses[3] + expenses[4]
print(Total)
# Out:
# 21123
